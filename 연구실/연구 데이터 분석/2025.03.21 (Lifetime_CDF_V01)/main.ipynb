# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import os

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# 파일 경로
file_legacy = "aodv_routing_log_l.csv"
file_proposed = "aodv_routing_log.csv"

# 로딩 함수
def load_and_process(file_path):
    if not os.path.exists(file_path):
        print(f"파일 없음: {file_path}")
        return None

    try:
        df = pd.read_csv(file_path, nrows=500)
    except Exception as e:
        print(f"파일 로딩 실패: {file_path}, 에러: {e}")
        return None

    def extract_node(x):
        match = re.search(r'\[(\d+)\]', str(x))
        return int(match.group(1)) if match else -1

    if 'Node' in df.columns:
        df['Node'] = df['Node'].apply(extract_node)

    if 'New_LifeTime' in df.columns and 'Previous_LifeTime' in df.columns:
        df['LifeTime_Change'] = df['New_LifeTime'] - df['Previous_LifeTime']
        return df['LifeTime_Change'].values
    else:
        print(f"LifeTime 컬럼 없음: {file_path}")
        return None

# 데이터 로딩
life_baseline = load_and_process(file_legacy)
life_proposed = load_and_process(file_proposed)

# CDF 계산 함수
def compute_cdf(data):
    sorted_data = np.sort(data)
    cdf = np.arange(1, len(sorted_data) + 1) / len(sorted_data)
    return sorted_data, cdf

# CDF 계산
if life_baseline is not None and life_proposed is not None:
    x_baseline, cdf_baseline = compute_cdf(life_baseline)
    x_proposed, cdf_proposed = compute_cdf(life_proposed)

    # 그래프 출력
    plt.figure(figsize=(8, 6))
    plt.plot(x_proposed, cdf_proposed, label="Proposed", linestyle='-', linewidth=1)
    plt.plot(x_baseline, cdf_baseline, label="Legacy AODV", linestyle='--', linewidth=1)
    plt.xlabel("LifeTime Change")
    plt.ylabel("CDF")
    plt.title("Proposed vs Legacy AODV LifeTime Change CDF")
    plt.legend()
    plt.grid(True)
    plt.show()
else:
    print("CDF를 그릴 수 없습니다. 데이터가 없습니다.")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import os

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# 파일 경로
file_legacy = "aodv_routing_log_l.csv"
file_proposed = "aodv_routing_log.csv"

# 로딩 함수
def load_and_process(file_path):
    if not os.path.exists(file_path):
        print(f"파일 없음: {file_path}")
        return None

    try:
        df = pd.read_csv(file_path, nrows=500)
    except Exception as e:
        print(f"파일 로딩 실패: {file_path}, 에러: {e}")
        return None

    def extract_node(x):
        match = re.search(r'\[(\d+)\]', str(x))
        return int(match.group(1)) if match else -1

    if 'Node' in df.columns:
        df['Node'] = df['Node'].apply(extract_node)

    if 'New_LifeTime' in df.columns and 'Previous_LifeTime' in df.columns:
        df['LifeTime_Change'] = df['New_LifeTime'] - df['Previous_LifeTime']
        return df['LifeTime_Change'].values
    else:
        print(f"LifeTime 컬럼 없음: {file_path}")
        return None

# 데이터 로딩
life_baseline = load_and_process(file_legacy)
life_proposed = load_and_process(file_proposed)

# CDF 계산 함수
def compute_cdf(data):
    sorted_data = np.sort(data)
    cdf = np.arange(1, len(sorted_data) + 1) / len(sorted_data)
    return sorted_data, cdf

# CDF 계산
if life_baseline is not None and life_proposed is not None:
    x_baseline, cdf_baseline = compute_cdf(life_baseline)
    x_proposed, cdf_proposed = compute_cdf(life_proposed)

    # 그래프 출력
    plt.figure(figsize=(8, 6))
    plt.plot(x_proposed, cdf_proposed, label="Proposed", linestyle='-', linewidth=1)
    plt.plot(x_baseline, cdf_baseline, label="Legacy AODV", linestyle='--', linewidth=1)
    plt.xlabel("LifeTime Change")
    plt.ylabel("CDF")
    plt.title("Proposed vs Legacy AODV LifeTime Change CDF")
    plt.legend()
    plt.grid(True)
    plt.show()
else:
    print("CDF를 그릴 수 없습니다. 데이터가 없습니다.")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import os

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# 파일 경로
file_legacy = "aodv_routing_log_l.csv"
file_proposed = "aodv_routing_log.csv"

# 로딩 함수
def load_and_process(file_path):
    if not os.path.exists(file_path):
        print(f"파일 없음: {file_path}")
        return None

    try:
        df = pd.read_csv(file_path, nrows=500)
    except Exception as e:
        print(f"파일 로딩 실패: {file_path}, 에러: {e}")
        return None

    def extract_node(x):
        match = re.search(r'\[(\d+)\]', str(x))
        return int(match.group(1)) if match else -1

    if 'Node' in df.columns:
        df['Node'] = df['Node'].apply(extract_node)

    if 'New_LifeTime' in df.columns and 'Previous_LifeTime' in df.columns:
        df['LifeTime_Change'] = df['New_LifeTime'] - df['Previous_LifeTime']
        return df['LifeTime_Change'].values
    else:
        print(f"LifeTime 컬럼 없음: {file_path}")
        return None

# 데이터 로딩
life_baseline = load_and_process(file_legacy)
life_proposed = load_and_process(file_proposed)

# CDF 계산 함수
def compute_cdf(data):
    sorted_data = np.sort(data)
    cdf = np.arange(1, len(sorted_data) + 1) / len(sorted_data)
    return sorted_data, cdf

# CDF 계산
if life_baseline is not None and life_proposed is not None:
    x_baseline, cdf_baseline = compute_cdf(life_baseline)
    x_proposed, cdf_proposed = compute_cdf(life_proposed)

    # 그래프 출력
    plt.figure(figsize=(8, 6))
    plt.plot(x_proposed, cdf_proposed, label="Proposed", linestyle='-', linewidth=1)
    plt.plot(x_baseline, cdf_baseline, label="Legacy AODV", linestyle='--', linewidth=1)
    plt.xlabel("LifeTime Change")
    plt.ylabel("CDF")
    plt.title("Proposed vs Legacy AODV LifeTime Change CDF")
    plt.legend()
    plt.grid(True)
    plt.show()
else:
    print("CDF를 그릴 수 없습니다. 데이터가 없습니다.")

# %%
import matplotlib.pyplot as plt
import numpy as np

categories = ['High Speed (30 km/h)', 'Medium Speed (20 km/h)', 'Low Speed (10 km/h)']
density_levels = ['High Density (400 vehicles)', 'Middle Density (300 vehicles)', 'Low Density (200 vehicles)']

existing = np.array([
    [73.77777778, 67, 84.44444444],
    [76.2, 75.3, 86.7],
    [82.1, 81.3, 95.3]
])

proposed = np.array([
    [82.66666667, 88.11111111, 91.77777778],
    [89, 88.6, 95.6],
    [87.1, 90.1, 96.8]
])

plt.figure(figsize=(10, 6))

colors = ['blue', 'green', 'red']

for i, level in enumerate(density_levels):
    plt.plot(categories, existing[i], marker='o', linestyle='-', color=colors[i], 
             label=f'Legacy - {level}', alpha=0.7)

for i, level in enumerate(density_levels):
    plt.plot(categories, proposed[i], marker='s', linestyle='--', color=colors[i], 
             label=f'Proposed - {level}', alpha=0.7)

plt.xlabel('Speed (km/h)')
plt.ylabel('Packet Delivery Ratio (PDR) %')
plt.title('Performance Comparison: Legacy AODV vs. Proposed')
plt.ylim(50, 100)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

categories = ['High Speed (30 km/h)', 'Medium Speed (20 km/h)', 'Low Speed (10 km/h)']
density_levels = ['High Density (400 vehicles)', 'Middle Density (300 vehicles)', 'Low Density (200 vehicles)']

existing = np.array([
    [67.8, 72.9, 77.1],
    [73.3, 71.6, 81.0],
    [86.7, 88.8, 92.1]
])

# 제안 기법 성능 데이터
proposed = np.array([
    [75.7, 87.4, 84.3],
    [83.0, 87.2, 87.9],
    [89.0, 95.9, 96.8]
])

plt.figure(figsize=(10, 6))

colors = ['blue', 'green', 'red']

for i, level in enumerate(density_levels):
    plt.plot(categories, existing[i], marker='o', linestyle='-', color=colors[i], 
             label=f'Legacy - {level}', alpha=0.7)

for i, level in enumerate(density_levels):
    plt.plot(categories, proposed[i], marker='s', linestyle='--', color=colors[i], 
             label=f'Proposed - {level}', alpha=0.7)

plt.xlabel('Maximum Speed (km/h)')
plt.ylabel('Packet Delivery Ratio (PDR) %')
plt.title('Performance Comparison: Legacy AODV vs. Proposed')
plt.ylim(50, 100)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
