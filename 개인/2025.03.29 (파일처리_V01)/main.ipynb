# %%
import matplotlib.pyplot as plt
import numpy as np

from collections import defaultdict

# %%
start_times = 'route_lifetime_start.txt'
end_times = 'route_lifetime_end.txt'

# %%
start_dict = defaultdict()
end_dict = defaultdict()

# %%
with open(start_times, 'r') as files :
    for line in files:
        tokens = line.strip().split(',')
        destination = tokens[0]
        node = int(tokens[1].split('[')[1].split(']')[0])
        times = float(tokens[2])
        start_dict[destination, node] = times

# %%
with open(end_times, 'r') as files :
    for line in files :
        tokens = line.strip().split(',')
        destination = tokens[0]
        node = int(tokens[1].split('[')[1].split(']')[0])
        times = float(tokens[2])
        end_dict[destination, node] = times

# %%
for key in start_dict:
    starts = start_dict[key]
    ends = end_dict.get(key)
    
    for start_time in starts:
        matched_end = None
        for i, end_dict in enumerate(ends) :
            if end_dict >
# Out:
# 103.622
# None
# 102.663
# 102.276
# 97.5533
# 56.3024
# 86.7264
# 102.743
# 35.4088
# 78.1135
# 70.4458
# 49.3833
# 48.0811
# 102.193
# 67.1848
# 78.1873
# 54.9752
# 100.513
# 72.4237
# 71.6618
# 167.194
# 102.663
# 57.4919
# 52.9876
# 81.1039
# 59.2612
# 35.4502
# 35.4457
# 46.9264
# 39.9358
# 52.0799
# 33.9434
# 48.2622
# 49.3176
# 68.3316
# 49.1143
# 48.1853
# 36.0579
# 34.7432
# 45.055
# 68.2826
# 49.6443
# 68.2825
# 78.2178
# 70.8256
# 34.7418
# 65.904
# 78.1855
# 40.0097
# 57.8305
# 102.663
# 38.1422
# 102.509
# 36.0898
# 71.7166
# 34.7451
# 77.5553
# 97.6268
# 41.9939
# 49.6634
# 36.7874
# 34.7722
# 55.6195
# 146.083
# 49.6443
# 58.4762
# 49.5657
# 58.0113
# None
# 48.3389
# 52.0786
# 77.015
# 32.5641
# 68.6366
# 48.0791
# 66.4639
# None
# 52.937
# 54.3624
# None
# 106.385
# 78.559
# 39.8571
# 42.7976
# 84.8274
# 62.2682
# 40.1386
# 129.565
# 88.8072
# 60.8143
# 50.3387
# 50.3387
# 66.6057
# 43.106
# 111.634
# 49.6538
# 49.6594
# 114.504
# 50.3726
# 43.6368
# 58.0089
# ...
